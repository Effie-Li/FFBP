# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib notebook

def unpickle(path):
    with open(path, 'rb') as f:
        runlog = pickle.load(f)
    return runlog

# %% [markdown]
# # Loading single loss log

# %%
path = '../xor/logdirs/ffbp_logdir_000/runlog_0.pkl'
loss = unpickle(path)['loss_data']
l, = plt.plot(loss)
# Out:
# <img src="data:image/png;base64,..." width="933.749986086041">

# %%
logdir_path = '../xor/logdirs/ffbp_logdir_000/'

paths = [logdir_path+'runlog_{}.pkl'.format(i) for i in range(3)]

losses = [unpickle(path)['loss_data'] for path in paths]

for loss in losses:
    plt.plot(loss)

# %%
path = '../xor/logdirs/ffbp_logdir_000/runlog_0.pkl'

runlog = unpickle(path)
test_data = runlog['test_data']
# print(test_data[-1]['enum'])

for k,v in test_data[0]['hidden_layer'].items():
    print('{}: {}'.format(k,v.shape))
# Out:
# input_: (4, 1, 2)
# weights: (2, 2)
# biases: (2,)
# net_input: (4, 1, 2)
# output: (4, 1, 2)
# gweights: (4, 2, 2)
# gbiases: (4, 2)
# gnet_input: (4, 1, 2)
# goutput: (4, 1, 2)
# sgweights: (2, 2)
# sgbiases: (2,)
