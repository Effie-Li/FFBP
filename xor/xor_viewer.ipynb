# %%
import os
import sys
import warnings
if '/Users/alexten/Projects/PDP' in sys.path: sys.path.remove('/Users/alexten/Projects/PDP')
if '/Users/alexten/Projects/pdpyflow' not in sys.path: sys.path.append('/Users/alexten/Projects/pdpyflow')
    
# from FFBP.utils import retrieve_array
import FFBP.vis_utils as vu

from IPython.display import display
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %matplotlib notebook

# %%
logdir = vu.Logdir()

# %%
vu.view_error(logdir)
# Out:
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/weights/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/biases/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/net_input/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/activations/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/weights/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/biases/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/net_input/tensor_summary' is oddly not associated with a plugin.
# ...

# %%
vu.view_layer(logdir, 'hidden_layer')
# Out:
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/weights/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/biases/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/net_input/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/activations/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/weights/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/biases/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/net_input/tensor_summary' is oddly not associated with a plugin.
# ...

# %%
# %%time

inp_size, out_size = 2, 2
i = np.random.rand(1,inp_size) - .5
w = np.random.rand(out_size,inp_size) - .5
b = np.random.rand(out_size,1) - .5
n = np.random.rand(out_size,1) - .5
a = np.random.rand(out_size,1) - .5

max_height, max_width = w.shape

fig = plt.figure(1, (5.5, 4.0))

# Axes grid is a rectangle placed inside a figure.
#   specify the position of the rectange in the figure:
#      lower-left corner coords:  x=0.1, y=0.1
#      upper-right corner coords: x=0.8, y=0.8
rect = (0.1, 0.1, 0.8, 0.8) 
axs = [fig.add_axes(rect, label='{}'.format(ii)) for ii in range(5)]

col_pad = Size.Scaled(.8)
row_pad = Size.Scaled(.8)
col_widths = [Size.Scaled(max_width), col_pad,
              Size.Scaled(1), col_pad,
              Size.Scaled(1), col_pad,
              Size.Scaled(1)]

row_heights = [Size.Scaled(1), row_pad,
               Size.Scaled(max_height)]

# divide the axes rectangle into grid whose size is specified by horiz * vert
divider = Divider(fig, rect, col_widths, row_heights, aspect=True)

axs[0].set_axes_locator(divider.new_locator(nx=0, ny=0))
axs[1].set_axes_locator(divider.new_locator(nx=0, ny=2))
axs[2].set_axes_locator(divider.new_locator(nx=2, ny=2))
axs[3].set_axes_locator(divider.new_locator(nx=4, ny=2))
axs[4].set_axes_locator(divider.new_locator(nx=6, ny=2))

axs[0].imshow(i, cmap='coolwarm', vmax=3, vmin=-3)
axs[1].imshow(w, cmap='coolwarm', vmax=3, vmin=-3)
axs[2].imshow(b, cmap='coolwarm', vmax=3, vmin=-3)
axs[3].imshow(n, cmap='coolwarm', vmax=3, vmin=-3)
axs[4].imshow(a, cmap='coolwarm', vmax=3, vmin=-3)

for ax in axs:
    ax.tick_params(
        axis='x',
        which='both',
        bottom='off',
        top='off',
        labelbottom='off',
        labeltop='off')
    ax.tick_params(
        axis='y',
        which='both',
        left='off',
        right='off',
        labelleft='off',
        labelright='off')
    

plt.draw()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# NameError: name 'np' is not defined

# %%
vu.view_layer(logdir, 'output_layer')
# Out:
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/weights/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/biases/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/net_input/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/hidden_layer/activations/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/weights/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/biases/tensor_summary' is oddly not associated with a plugin.
# WARNING:tensorflow:This summary with tag 'XOR_model/output_layer/net_input/tensor_summary' is oddly not associated with a plugin.
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.3.0'

# %%
# !tensorboard --logdir=/Users/Projects/pdpyflow/xor/train/log0
# Out:
# TensorBoard 0.1.6 at http://Alexs-MacBook-Pro.local:6006 (Press CTRL+C to quit)
