# %%
# %matplotlib notebook
import FFBP.vis_utils as vu

# %%
logdir = '../xor/logdirs/ffbp_logdir_000'
vu.view_layers(logdir, mode=0)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
import ipywidgets as widgets
from IPython.display import display

step1 = widgets.IntSlider(
    value=0,
    min=0,
    max=5,
    step=1,
    description='1: ',
)

step2 = widgets.IntSlider(
    value=5,
    min=0,
    max=5,
    step=1,
    description='1: ',
)


controls = dict(s1=step1, s2=step2, l=label)

def g(s1,s2, label):
    s = '{} {}'.format(s1, s2)
    label.value = s

sliders = widgets.HBox([step1, step2, label])

widgets.interactive_output(f=g, controls=controls)
display(sliders)
